# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Steps for read and initial cleaning from starter files
df = pd.read_csv("exoplanet_data.csv")

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# View columns of the df
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# # Select your features (columns)

# %%
# Set features, determining features to use for X 

# Want to drop the y target and one additional column (TCE Planet Number)
X = df.drop(columns=['koi_disposition', 'koi_tce_plnt_num']
           )
X
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1        1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3        3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4        1.050000e-05    -1.050000e-05   172.979370          0.001900
# ...               ...              ...          ...               ...
# 6986     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 6987     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 6988     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 6989     2.430000e-06    -2.430000e-06   132.181750          0.002850
# 6990     6.360000e-05    -6.360000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0            -0.003520  ...             -81      4.467           0.064
# 1            -0.000581  ...            -176      4.544           0.044
# 2            -0.000115  ...            -174      4.564           0.053
# 3            -0.001130  ...            -211      4.438           0.070
# 4            -0.001900  ...            -232      4.486           0.054
# ...                ...  ...             ...        ...             ...
# 6986         -0.015700  ...            -152      4.296           0.231
# 6987         -0.000170  ...            -166      4.529           0.035
# 6988         -0.007690  ...            -220      4.444           0.056
# 6989         -0.002850  ...            -236      4.447           0.056
# 6990         -0.010800  ...            -225      4.385           0.054
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0             -0.096     0.927          0.105         -0.061  291.93423
# 1             -0.176     0.868          0.233         -0.078  297.00482
# 2             -0.168     0.791          0.201         -0.067  285.53461
# 3             -0.210     1.046          0.334         -0.133  288.75488
# 4             -0.229     0.972          0.315         -0.105  296.28613
# ...              ...       ...            ...            ...        ...
# 6986          -0.189     1.088          0.313         -0.228  298.74921
# 6987          -0.196     0.903          0.237         -0.079  297.18875
# 6988          -0.224     1.031          0.341         -0.114  286.50937
# 6989          -0.224     1.041          0.341         -0.114  294.16489
# 6990          -0.216     1.193          0.410         -0.137  297.00977
#
#             dec  koi_kepmag
# 0     48.141651      15.347
# 1     48.134129      15.436
# 2     48.285210      15.597
# 3     48.226200      15.509
# 4     48.224670      15.714
# ...         ...         ...
# 6986  46.973351      14.478
# 6987  47.093819      14.082
# 6988  47.163219      14.757
# 6989  47.176281      15.385
# 6990  47.121021      14.826
#
# [6991 rows x 39 columns]

# %%
# Determining features to use for X (dropping y target and other columns which were the uncertainties)

# X = df.drop(columns=['koi_disposition', 'koi_tce_plnt_num', 'koi_period_err1', 'koi_period_err2', 
#             'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact_err1', 'koi_impact_err2',
#             'koi_depth_err1', 'koi_depth_err2', 'koi_duration_err1', 'koi_duration_err2',
#             'koi_prad_err1', 'koi_prad_err2', 'koi_insol_err1', 'koi_insol_err2', 
#             'koi_steff_err1', 'koi_steff_err2', 'koi_slogg_err1', 'koi_slogg_err2',
#             'koi_srad_err1', 'koi_srad_err2']
#            )
# X

# Results not as strong once the uncertainties were droppped

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y=df.koi_disposition
y
# Out:
# 0            CONFIRMED
# 1       FALSE POSITIVE
# 2       FALSE POSITIVE
# 3            CONFIRMED
# 4            CONFIRMED
#              ...
# 6986    FALSE POSITIVE
# 6987    FALSE POSITIVE
# 6988         CANDIDATE
# 6989    FALSE POSITIVE
# 6990    FALSE POSITIVE
# Name: koi_disposition, Length: 6991, dtype: object

# %%
y.value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.head(20)
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3563              0              0              0              0   10.548413
# 4099              0              0              0              0   24.754385
# 5460              0              0              0              0    1.057336
# 1091              0              0              0              0  201.118319
# 5999              0              0              0              0   91.649983
# 2637              0              0              0              0    9.940666
# 6889              1              0              0              0  358.743180
# 192               0              0              0              0   10.848452
# 3833              0              0              0              0  214.312044
# 2917              0              0              0              0   20.485389
# 2742              1              0              1              0    0.907944
# 2223              0              0              0              0    6.232123
# 6551              0              0              0              1    1.213743
# 3119              0              0              0              0   54.333582
# 6250              1              0              0              0  224.591055
# 4953              1              0              0              0   22.863152
# 1310              0              1              1              0    3.979868
# 6803              0              1              0              0    0.590282
# 4143              0              0              1              0    1.099291
# 3698              0              1              0              0    2.637574
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3563     5.470000e-05    -5.470000e-05   139.064020          0.004110
# 4099     1.365000e-04    -1.365000e-04   140.207320          0.004460
# 5460     1.230000e-07    -1.230000e-07   131.792007          0.000096
# 1091     1.461000e-03    -1.461000e-03   187.569860          0.005290
# 5999     3.181000e-03    -3.181000e-03   175.715600          0.028600
# 2637     6.980000e-06    -6.980000e-06   135.215590          0.000582
# 6889     4.849000e-02    -4.849000e-02   150.554000          0.064300
# 192      1.630000e-05    -1.630000e-05   171.805840          0.001220
# 3833     1.427000e-04    -1.427000e-04   336.330158          0.000427
# 2917     3.165000e-04    -3.165000e-04   146.918300          0.011800
# 2742     1.010000e-06    -1.010000e-06   132.133484          0.000964
# 2223     1.250000e-04    -1.250000e-04   135.236900          0.013600
# 6551     8.820000e-06    -8.820000e-06   131.741230          0.007790
# 3119     1.271000e-03    -1.271000e-03   144.753600          0.019400
# 6250     3.490000e-03    -3.490000e-03   208.790400          0.015900
# 4953     3.594000e-04    -3.594000e-04   143.152300          0.010600
# 1310     4.370000e-06    -4.370000e-06   132.071233          0.000892
# 6803     4.060000e-06    -4.060000e-06   131.691270          0.006540
# 4143     4.340000e-06    -4.340000e-06   131.502420          0.003140
# 3698     3.630000e-07    -3.630000e-07   131.575561          0.000125
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 3563         -0.004110  ...            -133      4.387           0.066
# 4099         -0.004460  ...            -144      4.519           0.078
# 5460         -0.000096  ...            -140      4.594           0.054
# 1091         -0.005290  ...            -112      4.447           0.072
# 5999         -0.028600  ...            -233      4.145           0.164
# 2637         -0.000582  ...            -136      4.305           0.080
# 6889         -0.064300  ...            -147      4.566           0.038
# 192          -0.001220  ...            -416      4.682           0.088
# 3833         -0.000427  ...            -141      4.287           0.063
# 2917         -0.011800  ...             -79      3.450           0.143
# 2742         -0.000964  ...            -213      4.354           0.084
# 2223         -0.013600  ...            -127      4.421           0.040
# 6551         -0.007790  ...            -195      3.961           0.266
# 3119         -0.019400  ...             -66      4.228           0.195
# 6250         -0.015900  ...            -157      3.992           0.285
# 4953         -0.010600  ...            -176      3.339           0.303
# 1310         -0.000892  ...            -210      4.485           0.054
# 6803         -0.006540  ...            -184      4.196           0.198
# 4143         -0.003140  ...            -145      4.500           0.077
# 3698         -0.000125  ...            -188      4.509           0.036
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 3563          -0.123     1.092          0.181         -0.097  298.09543
# 4099          -0.052     0.804          0.056         -0.076  295.73535
# 5460          -0.027     0.683          0.054         -0.060  292.18417
# 1091          -0.108     0.954          0.135         -0.083  283.11377
# 5999          -0.164     1.608          0.905         -0.383  294.93198
# 2637          -0.120     1.259          0.219         -0.128  284.55573
# 6889          -0.152     0.826          0.188         -0.063  291.28595
# 192           -0.072     0.591          0.109         -0.109  295.57935
# 3833          -0.117     1.357          0.242         -0.138  290.97394
# 2917          -0.130     3.324          0.613         -0.551  290.62183
# 2742          -0.210     1.166          0.378         -0.162  297.36047
# 2223          -0.120     1.084          0.177         -0.071  287.97885
# 6551          -0.114     1.987          0.422         -0.633  283.66428
# 3119          -0.120     1.221          0.193         -0.236  285.15942
# 6250          -0.095     1.771          0.300         -0.557  294.86639
# 4953          -0.274     4.874          2.186         -2.021  288.14200
# 1310          -0.216     0.973          0.315         -0.105  295.64020
# 6803          -0.132     1.315          0.295         -0.295  286.47849
# 4143          -0.049     0.843          0.056         -0.084  290.23300
# 3698          -0.192     0.953          0.264         -0.088  293.66934
#
#             dec  koi_kepmag
# 3563  44.737061      13.204
# 4099  42.576248      15.514
# 5460  49.310040      15.414
# 1091  48.131390      13.328
# 5999  39.812420      12.964
# 2637  46.063831      12.663
# 6889  46.920551      14.806
# 192   44.545959      15.058
# 3833  48.178162      12.040
# 2917  51.057301      13.007
# 2742  40.056141      13.819
# 2223  42.679359      12.857
# 6551  47.400970      13.203
# 3119  47.882740      14.487
# 6250  44.980991      12.238
# 4953  51.245602      12.260
# 1310  40.794842      14.782
# 6803  49.641140      12.174
# 4143  52.336010      15.496
# 3698  46.297459      15.902
#
# [20 rows x 39 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler

# %%
# Scale data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Look at a row of the results to see the array
X_train_scaled[0]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        9.56989489e-03, 4.08052303e-04, 9.99591948e-01, 1.36824641e-02,
#        7.20801882e-03, 9.92791981e-01, 1.00886852e-02, 5.99107712e-04,
#        9.86749831e-01, 1.43641964e-02, 7.07920792e-03, 9.92920792e-01,
#        6.18920878e-05, 2.67627380e-05, 9.99973237e-01, 1.87176316e-05,
#        3.71853547e-05, 9.99995595e-01, 5.53687822e-02, 1.41419711e-05,
#        2.01209102e-05, 9.99993057e-01, 1.11563995e-03, 3.89374425e-01,
#        1.77514793e-01, 9.23254472e-01, 8.16249765e-01, 4.48369565e-02,
#        8.48522167e-01, 5.46402526e-03, 6.97333950e-03, 9.99065736e-01,
#        8.34972972e-01, 5.17791237e-01, 5.15579800e-01])

# %% [markdown]
# # Train the Model

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Model Accuracy
print(f'Training Data Score: {model.score(X_train_scaled, y_train)}')
print(f'Testing Data Score: {model.score(X_test_scaled, y_test)}')
# Out:
# Training Data Score: 0.8371161548731643
# Testing Data Score: 0.8564073226544623

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
# Use shift tab to explore more of the options that can be updated here
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C':[1,5,10,15], 'tol':[.01, .001, .0001]}
grid = GridSearchCV(model,param_grid,verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END .....................C=1, tol=0.01;, score=0.848 total time=   0.1s
# [CV 2/5] END .....................C=1, tol=0.01;, score=0.845 total time=   0.1s
# [CV 3/5] END .....................C=1, tol=0.01;, score=0.820 total time=   0.1s
# [CV 4/5] END .....................C=1, tol=0.01;, score=0.818 total time=   0.1s
# [CV 5/5] END .....................C=1, tol=0.01;, score=0.832 total time=   0.1s
# [CV 1/5] END ....................C=1, tol=0.001;, score=0.848 total time=   0.1s
# [CV 2/5] END ....................C=1, tol=0.001;, score=0.844 total time=   0.1s
# [CV 3/5] END ....................C=1, tol=0.001;, score=0.820 total time=   0.1s
# [CV 4/5] END ....................C=1, tol=0.001;, score=0.818 total time=   0.1s
# [CV 5/5] END ....................C=1, tol=0.001;, score=0.832 total time=   0.1s
# [CV 1/5] END ...................C=1, tol=0.0001;, score=0.848 total time=   0.2s
# [CV 2/5] END ...................C=1, tol=0.0001;, score=0.844 total time=   0.2s
# [CV 3/5] END ...................C=1, tol=0.0001;, score=0.820 total time=   0.2s
# [CV 4/5] END ...................C=1, tol=0.0001;, score=0.818 total time=   0.2s
# [CV 5/5] END ...................C=1, tol=0.0001;, score=0.832 total time=   0.2s
# [CV 1/5] END .....................C=5, tol=0.01;, score=0.867 total time=   0.1s
# [CV 2/5] END .....................C=5, tol=0.01;, score=0.876 total time=   0.1s
# [CV 3/5] END .....................C=5, tol=0.01;, score=0.850 total time=   0.1s
# [CV 4/5] END .....................C=5, tol=0.01;, score=0.849 total time=   0.1s
# [CV 5/5] END .....................C=5, tol=0.01;, score=0.847 total time=   0.1s
# [CV 1/5] END ....................C=5, tol=0.001;, score=0.867 total time=   0.1s
# [CV 2/5] END ....................C=5, tol=0.001;, score=0.877 total time=   0.2s
# [CV 3/5] END ....................C=5, tol=0.001;, score=0.853 total time=   0.2s
# [CV 4/5] END ....................C=5, tol=0.001;, score=0.849 total time=   0.2s
# [CV 5/5] END ....................C=5, tol=0.001;, score=0.847 total time=   0.1s
# [CV 1/5] END ...................C=5, tol=0.0001;, score=0.867 total time=   0.2s
# [CV 2/5] END ...................C=5, tol=0.0001;, score=0.877 total time=   0.3s
# [CV 3/5] END ...................C=5, tol=0.0001;, score=0.853 total time=   0.2s
# [CV 4/5] END ...................C=5, tol=0.0001;, score=0.849 total time=   0.3s
# [CV 5/5] END ...................C=5, tol=0.0001;, score=0.847 total time=   0.2s
# [CV 1/5] END ....................C=10, tol=0.01;, score=0.869 total time=   0.1s
# [CV 2/5] END ....................C=10, tol=0.01;, score=0.882 total time=   0.1s
# [CV 3/5] END ....................C=10, tol=0.01;, score=0.857 total time=   0.1s
# [CV 4/5] END ....................C=10, tol=0.01;, score=0.859 total time=   0.1s
# [CV 5/5] END ....................C=10, tol=0.01;, score=0.856 total time=   0.1s
# [CV 1/5] END ...................C=10, tol=0.001;, score=0.870 total time=   0.1s
# [CV 2/5] END ...................C=10, tol=0.001;, score=0.882 total time=   0.2s
# [CV 3/5] END ...................C=10, tol=0.001;, score=0.857 total time=   0.2s
# [CV 4/5] END ...................C=10, tol=0.001;, score=0.859 total time=   0.2s
# [CV 5/5] END ...................C=10, tol=0.001;, score=0.858 total time=   0.1s
# [CV 1/5] END ..................C=10, tol=0.0001;, score=0.870 total time=   0.4s
# [CV 2/5] END ..................C=10, tol=0.0001;, score=0.882 total time=   0.3s
# [CV 3/5] END ..................C=10, tol=0.0001;, score=0.857 total time=   0.4s
# [CV 4/5] END ..................C=10, tol=0.0001;, score=0.858 total time=   0.4s
# [CV 5/5] END ..................C=10, tol=0.0001;, score=0.858 total time=   0.2s
# [CV 1/5] END ....................C=15, tol=0.01;, score=0.872 total time=   0.1s
# [CV 2/5] END ....................C=15, tol=0.01;, score=0.886 total time=   0.1s
# [CV 3/5] END ....................C=15, tol=0.01;, score=0.867 total time=   0.1s
# [CV 4/5] END ....................C=15, tol=0.01;, score=0.864 total time=   0.1s
# [CV 5/5] END ....................C=15, tol=0.01;, score=0.861 total time=   0.1s
# [CV 1/5] END ...................C=15, tol=0.001;, score=0.872 total time=   0.2s
# [CV 2/5] END ...................C=15, tol=0.001;, score=0.887 total time=   0.2s
# [CV 3/5] END ...................C=15, tol=0.001;, score=0.867 total time=   0.2s
# [CV 4/5] END ...................C=15, tol=0.001;, score=0.863 total time=   0.2s
# [CV 5/5] END ...................C=15, tol=0.001;, score=0.861 total time=   0.2s
# [CV 1/5] END ..................C=15, tol=0.0001;, score=0.872 total time=   1.0s
# [CV 2/5] END ..................C=15, tol=0.0001;, score=0.887 total time=   0.7s
# [CV 3/5] END ..................C=15, tol=0.0001;, score=0.868 total time=   0.7s
# [CV 4/5] END ..................C=15, tol=0.0001;, score=0.863 total time=   0.8s
# [CV 5/5] END ..................C=15, tol=0.0001;, score=0.861 total time=   0.6s
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [1, 5, 10, 15], 'tol': [0.01, 0.001, 0.0001]},
#              verbose=3)

# %%
# print(grid.best_params_)
print('Best C:', grid.best_estimator_.get_params()['C'])
print(grid.best_score_)
# Out:
# Best C: 15
# 0.8701093007517156

# %%
y.value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %%
target_names = ['FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE']
# Calculate classification report
from sklearn.metrics import classification_report

# From the model, before hyperparameter tuning
predictions = model.predict(X_test_scaled)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
# FALSE POSITIVE       0.76      0.58      0.66       404
#      CONFIRMED       0.68      0.82      0.74       435
#      CANDIDATE       0.99      1.00      0.99       909
#
#       accuracy                           0.86      1748
#      macro avg       0.81      0.80      0.80      1748
#   weighted avg       0.86      0.86      0.85      1748

# %%
# Calculate classification report, the model "grid"/after hyperparameter tuning
predictions = grid.predict(X_test_scaled)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
# FALSE POSITIVE       0.89      0.61      0.72       404
#      CONFIRMED       0.72      0.91      0.80       435
#      CANDIDATE       0.99      1.00      0.99       909
#
#       accuracy                           0.89      1748
#      macro avg       0.86      0.84      0.84      1748
#   weighted avg       0.90      0.89      0.88      1748

# %% [markdown]
# # Save the Model

# %%
# save model for submitting to BCS
# This model is the better when compared to Linear Regression model
import joblib
filename = 'SVC.sav'
joblib.dump(grid, filename)
# Out:
# ['SVC.sav']
