# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Steps for read and initial cleaning from starter files
df = pd.read_csv("exoplanet_data.csv")

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# # Select your features (columns)

# %%
# Determining features to use for X (dropping y target and other columns)

# X = df.drop(columns=['koi_disposition', 'koi_tce_plnt_num', 'koi_period_err1', 'koi_period_err2', 
#             'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact_err1', 'koi_impact_err2',
#             'koi_depth_err1', 'koi_depth_err2', 'koi_duration_err1', 'koi_duration_err2',
#             'koi_prad_err1', 'koi_prad_err2', 'koi_insol_err1', 'koi_insol_err2', 
#             'koi_steff_err1', 'koi_steff_err2', 'koi_slogg_err1', 'koi_slogg_err2',
#             'koi_srad_err1', 'koi_srad_err2']
#            )
# X

# Results not as strong once the uncertainties were droppped
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 0      162.513840       0.586       4.50700      874.8      2.83      443
# 1      175.850252       0.969       1.78220    10829.0     14.60      638
# 2      170.307565       1.276       2.40641     8079.2     33.46     1395
# 3      171.595550       0.701       1.65450      603.3      2.75     1406
# 4      172.979370       0.762       3.14020      686.0      2.77     1160
# ...           ...         ...           ...        ...       ...      ...
# 6986   132.016100       0.765       4.80600       87.7      1.11      929
# 6987   131.705093       1.252       3.22210     1579.2     29.35     2088
# 6988   133.001270       0.043       3.11400       48.5      0.72     1608
# 6989   132.181750       0.147       0.86500      103.6      1.07     2218
# 6990   135.993300       0.134       3.07800       76.7      1.05     1266
#
#       koi_insol  koi_model_snr  koi_steff  koi_slogg  koi_srad         ra  \
# 0          9.11           25.8       5455      4.467     0.927  291.93423
# 1         39.30           76.3       5853      4.544     0.868  297.00482
# 2        891.96          505.6       5805      4.564     0.791  285.53461
# 3        926.16           40.9       6031      4.438     1.046  288.75488
# 4        427.65           40.2       6046      4.486     0.972  296.28613
# ...         ...            ...        ...        ...       ...        ...
# 6986     176.40            8.4       5638      4.296     1.088  298.74921
# 6987    4500.53          453.3       5638      4.529     0.903  297.18875
# 6988    1585.81           10.6       6119      4.444     1.031  286.50937
# 6989    5713.41           12.3       6173      4.447     1.041  294.16489
# 6990     607.42            8.2       6469      4.385     1.193  297.00977
#
#             dec  koi_kepmag
# 0     48.141651      15.347
# 1     48.134129      15.436
# 2     48.285210      15.597
# 3     48.226200      15.509
# 4     48.224670      15.714
# ...         ...         ...
# 6986  46.973351      14.478
# 6987  47.093819      14.082
# 6988  47.163219      14.757
# 6989  47.176281      15.385
# 6990  47.121021      14.826
#
# [6991 rows x 19 columns]

# %%
# Set features, determining features to use for X 

# Want to drop the y target and one additional column (TCE Planet Number)
X = df.drop(columns=['koi_disposition', 'koi_tce_plnt_num']
           )
X
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1        1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3        3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4        1.050000e-05    -1.050000e-05   172.979370          0.001900
# ...               ...              ...          ...               ...
# 6986     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 6987     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 6988     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 6989     2.430000e-06    -2.430000e-06   132.181750          0.002850
# 6990     6.360000e-05    -6.360000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0            -0.003520  ...             -81      4.467           0.064
# 1            -0.000581  ...            -176      4.544           0.044
# 2            -0.000115  ...            -174      4.564           0.053
# 3            -0.001130  ...            -211      4.438           0.070
# 4            -0.001900  ...            -232      4.486           0.054
# ...                ...  ...             ...        ...             ...
# 6986         -0.015700  ...            -152      4.296           0.231
# 6987         -0.000170  ...            -166      4.529           0.035
# 6988         -0.007690  ...            -220      4.444           0.056
# 6989         -0.002850  ...            -236      4.447           0.056
# 6990         -0.010800  ...            -225      4.385           0.054
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0             -0.096     0.927          0.105         -0.061  291.93423
# 1             -0.176     0.868          0.233         -0.078  297.00482
# 2             -0.168     0.791          0.201         -0.067  285.53461
# 3             -0.210     1.046          0.334         -0.133  288.75488
# 4             -0.229     0.972          0.315         -0.105  296.28613
# ...              ...       ...            ...            ...        ...
# 6986          -0.189     1.088          0.313         -0.228  298.74921
# 6987          -0.196     0.903          0.237         -0.079  297.18875
# 6988          -0.224     1.031          0.341         -0.114  286.50937
# 6989          -0.224     1.041          0.341         -0.114  294.16489
# 6990          -0.216     1.193          0.410         -0.137  297.00977
#
#             dec  koi_kepmag
# 0     48.141651      15.347
# 1     48.134129      15.436
# 2     48.285210      15.597
# 3     48.226200      15.509
# 4     48.224670      15.714
# ...         ...         ...
# 6986  46.973351      14.478
# 6987  47.093819      14.082
# 6988  47.163219      14.757
# 6989  47.176281      15.385
# 6990  47.121021      14.826
#
# [6991 rows x 39 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y=df.koi_disposition
y
# Out:
# 0            CONFIRMED
# 1       FALSE POSITIVE
# 2       FALSE POSITIVE
# 3            CONFIRMED
# 4            CONFIRMED
#              ...
# 6986    FALSE POSITIVE
# 6987    FALSE POSITIVE
# 6988         CANDIDATE
# 6989    FALSE POSITIVE
# 6990    FALSE POSITIVE
# Name: koi_disposition, Length: 6991, dtype: object

# %%
y.value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head(20)
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
# 6291              0              1              0              0   45.433249
# 5193              0              0              0              0   78.866840
# 2505              0              1              0              0   19.193104
# 2984              0              0              0              0    7.298142
# 2699              0              0              0              0    7.751928
# 751               0              0              0              0   10.561372
# 6040              0              1              0              0    1.427966
# 584               0              1              0              0    5.117402
# 1220              0              0              0              0    1.653889
# 6639              1              0              0              0  197.377040
# 2389              0              0              0              0    3.250582
# 5787              0              0              0              0    0.784301
# 6005              0              1              1              0   10.348211
# 548               0              1              1              0    9.991625
# 5405              0              0              0              0  502.206420
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
0]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        8.04827937e-03, 6.12356902e-04, 9.99387643e-01, 9.29087782e-03,
#        1.48179770e-02, 9.85182023e-01, 1.48800667e-03, 3.56558335e-03,
#        9.97471342e-01, 2.49253828e-02, 1.51485149e-02, 9.84851485e-01,
#        7.48673780e-05, 3.39680906e-05, 9.99966032e-01, 5.29085159e-06,
#        1.94508009e-05, 9.99997020e-01, 7.06538344e-02, 3.53462957e-05,
#        1.16933390e-04, 9.99981452e-01, 1.06796680e-03, 2.32414054e-01,
#        2.27810651e-01, 8.87425938e-01, 8.04965206e-01, 1.03940217e-01,
#        7.69704433e-01, 5.64745642e-03, 1.19432886e-02, 9.98006261e-01,
#        6.65745671e-01, 1.76049579e-01, 6.41292669e-01])

# %% [markdown]
# # Train the Model

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Model Accuracy
model.score(X_train_scaled, y_train)
print('Test Acc: %.3f' % model.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.834

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
# Use shift tab to explore more of the options that can be updated here
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C':[1,5,10], 'tol':[.01, .001, .0001]}
grid = GridSearchCV(model,param_grid,verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END .....................C=1, tol=0.01;, score=0.854 total time=   0.1s
# [CV 2/5] END .....................C=1, tol=0.01;, score=0.832 total time=   0.1s
# [CV 3/5] END .....................C=1, tol=0.01;, score=0.855 total time=   0.1s
# [CV 4/5] END .....................C=1, tol=0.01;, score=0.833 total time=   0.1s
# [CV 5/5] END .....................C=1, tol=0.01;, score=0.835 total time=   0.1s
# [CV 1/5] END ....................C=1, tol=0.001;, score=0.854 total time=   0.1s
# [CV 2/5] END ....................C=1, tol=0.001;, score=0.832 total time=   0.1s
# [CV 3/5] END ....................C=1, tol=0.001;, score=0.855 total time=   0.1s
# [CV 4/5] END ....................C=1, tol=0.001;, score=0.832 total time=   0.1s
# [CV 5/5] END ....................C=1, tol=0.001;, score=0.836 total time=   0.2s
# [CV 1/5] END ...................C=1, tol=0.0001;, score=0.854 total time=   0.3s
# [CV 2/5] END ...................C=1, tol=0.0001;, score=0.832 total time=   0.2s
# [CV 3/5] END ...................C=1, tol=0.0001;, score=0.855 total time=   0.2s
# [CV 4/5] END ...................C=1, tol=0.0001;, score=0.832 total time=   0.2s
# [CV 5/5] END ...................C=1, tol=0.0001;, score=0.836 total time=   0.3s
# [CV 1/5] END .....................C=5, tol=0.01;, score=0.881 total time=   0.1s
# [CV 2/5] END .....................C=5, tol=0.01;, score=0.856 total time=   0.1s
# [CV 3/5] END .....................C=5, tol=0.01;, score=0.875 total time=   0.1s
# [CV 4/5] END .....................C=5, tol=0.01;, score=0.850 total time=   0.1s
# [CV 5/5] END .....................C=5, tol=0.01;, score=0.862 total time=   0.1s
# [CV 1/5] END ....................C=5, tol=0.001;, score=0.881 total time=   0.1s
# [CV 2/5] END ....................C=5, tol=0.001;, score=0.855 total time=   0.1s
# [CV 3/5] END ....................C=5, tol=0.001;, score=0.875 total time=   0.1s
# [CV 4/5] END ....................C=5, tol=0.001;, score=0.850 total time=   0.1s
# [CV 5/5] END ....................C=5, tol=0.001;, score=0.862 total time=   0.2s
# [CV 1/5] END ...................C=5, tol=0.0001;, score=0.881 total time=   0.3s
# [CV 2/5] END ...................C=5, tol=0.0001;, score=0.855 total time=   0.2s
# [CV 3/5] END ...................C=5, tol=0.0001;, score=0.875 total time=   0.2s
# [CV 4/5] END ...................C=5, tol=0.0001;, score=0.850 total time=   0.1s
# [CV 5/5] END ...................C=5, tol=0.0001;, score=0.862 total time=   0.2s
# [CV 1/5] END ....................C=10, tol=0.01;, score=0.891 total time=   0.1s
# [CV 2/5] END ....................C=10, tol=0.01;, score=0.858 total time=   0.1s
# [CV 3/5] END ....................C=10, tol=0.01;, score=0.884 total time=   0.1s
# [CV 4/5] END ....................C=10, tol=0.01;, score=0.854 total time=   0.1s
# [CV 5/5] END ....................C=10, tol=0.01;, score=0.867 total time=   0.1s
# [CV 1/5] END ...................C=10, tol=0.001;, score=0.891 total time=   0.2s
# [CV 2/5] END ...................C=10, tol=0.001;, score=0.858 total time=   0.1s
# [CV 3/5] END ...................C=10, tol=0.001;, score=0.884 total time=   0.2s
# [CV 4/5] END ...................C=10, tol=0.001;, score=0.854 total time=   0.2s
# [CV 5/5] END ...................C=10, tol=0.001;, score=0.866 total time=   0.2s
# [CV 1/5] END ..................C=10, tol=0.0001;, score=0.891 total time=   0.3s
# [CV 2/5] END ..................C=10, tol=0.0001;, score=0.858 total time=   0.3s
# [CV 3/5] END ..................C=10, tol=0.0001;, score=0.884 total time=   0.4s
# [CV 4/5] END ..................C=10, tol=0.0001;, score=0.854 total time=   0.2s
# [CV 5/5] END ..................C=10, tol=0.0001;, score=0.866 total time=   0.3s
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [1, 5, 10], 'tol': [0.01, 0.001, 0.0001]},
#              verbose=3)

# %%
#print(grid.best_params_)
print('Best C:', grid.best_estimator_.get_params()['C'])
print(grid.best_score_)
# Out:
# Best C: 10
# 0.8708715679782273

# %%
y.value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %%
target_names = ['FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE']
# Calculate classification report
from sklearn.metrics import classification_report

# From the model, before hyperparameter tuning
predictions = model.predict(X_test_scaled)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
# FALSE POSITIVE       0.69      0.59      0.64       411
#      CONFIRMED       0.69      0.75      0.72       484
#      CANDIDATE       0.98      1.00      0.99       853
#
#       accuracy                           0.83      1748
#      macro avg       0.79      0.78      0.78      1748
#   weighted avg       0.83      0.83      0.83      1748

# %%
# Calculate classification report, the model "grid"/after hyperparameter tuning
predictions = grid.predict(X_test_scaled)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
# FALSE POSITIVE       0.80      0.62      0.70       411
#      CONFIRMED       0.73      0.85      0.79       484
#      CANDIDATE       0.98      1.00      0.99       853
#
#       accuracy                           0.87      1748
#      macro avg       0.84      0.82      0.83      1748
#   weighted avg       0.87      0.87      0.87      1748

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash

# Looking at other models before saving the best version
import joblib
filename = 'SVC.sav'
joblib.dump(grid, filename)
# Out:
# ['SVC.sav']
